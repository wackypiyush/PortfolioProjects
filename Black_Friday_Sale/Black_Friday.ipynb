# %% [markdown]
# # Dataset History
# ### A retail company “ABC Private Limited” wants to understand the customer purchase behavior (specifically, purchase amount) against various products of different categories. They have shared purchase summaries of various customers for selected high-volume products from last month.
# ### The data set also contains customer demographics (age, gender, marital status, city type, stayincurrentcity), product details (productid and product category), and Total purchase amount from last month.
#
# #### Dataset Link: https://www.kaggle.com/datasets/rajeshrampure/black-friday-sale

# %%
# Importing Libraries

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O
import matplotlib.pyplot as plt
import seaborn as sns
from pprint import pprint

plt.style.use('classic')

# %%
# Importing Dataset

sale= pd.read_csv("Black_Friday.csv")

# %%
display(sale)
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# 1                               2               0                   1
# 2                               2               0                  12
# 3                               2               0                  12
# 4                              4+               0                   8
# ...                           ...             ...                 ...
# 550063                          1               1                  20
# 550064                          3               0                  20
# 550065                         4+               1                  20
# 550066                          2               0                  20
# 550067                         4+               1                  20
#
#         Product_Category_2  Product_Category_3  Purchase
# 0                      NaN                 NaN      8370
# 1                      6.0                14.0     15200
# 2                      NaN                 NaN      1422
# 3                     14.0                 NaN      1057
# 4                      NaN                 NaN      7969
# ...                    ...                 ...       ...
# 550063                 NaN                 NaN       368
# 550064                 NaN                 NaN       371
# 550065                 NaN                 NaN       137
# 550066                 NaN                 NaN       365
# 550067                 NaN                 NaN       490
#
# [550068 rows x 12 columns]

# %%
# Info of Dataset

sale.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550068 entries, 0 to 550067
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     550068 non-null  int64
#  1   Product_ID                  550068 non-null  object
#  2   Gender                      550068 non-null  object
#  3   Age                         550068 non-null  object
#  4   Occupation                  550068 non-null  int64
#  5   City_Category               550068 non-null  object
#  6   Stay_In_Current_City_Years  550068 non-null  object
#  7   Marital_Status              550068 non-null  int64
#  8   Product_Category_1          550068 non-null  int64
#  9   Product_Category_2          376430 non-null  float64
#  10  Product_Category_3          166821 non-null  float64
#  11  Purchase                    550068 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# memory usage: 50.4+ MB

# %%
display(sale.describe())
# Out:
#             User_ID     Occupation  Marital_Status  Product_Category_1  \
# count  5.500680e+05  550068.000000   550068.000000       550068.000000
# mean   1.003029e+06       8.076707        0.409653            5.404270
# std    1.727592e+03       6.522660        0.491770            3.936211
# min    1.000001e+06       0.000000        0.000000            1.000000
# 25%    1.001516e+06       2.000000        0.000000            1.000000
# 50%    1.003077e+06       7.000000        0.000000            5.000000
# 75%    1.004478e+06      14.000000        1.000000            8.000000
# max    1.006040e+06      20.000000        1.000000           20.000000
#
#        Product_Category_2  Product_Category_3       Purchase
# count       376430.000000       166821.000000  550068.000000
# mean             9.842329           12.668243    9263.968713
# std              5.086590            4.125338    5023.065394
# min              2.000000            3.000000      12.000000
# 25%              5.000000            9.000000    5823.000000
# 50%              9.000000           14.000000    8047.000000
# 75%             15.000000           16.000000   12054.000000
# max             18.000000           18.000000   23961.000000

# %%
# Dropping if any row is duplicate

display(sale.drop_duplicates())
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# 1                               2               0                   1
# 2                               2               0                  12
# 3                               2               0                  12
# 4                              4+               0                   8
# ...                           ...             ...                 ...
# 550063                          1               1                  20
# 550064                          3               0                  20
# 550065                         4+               1                  20
# 550066                          2               0                  20
# 550067                         4+               1                  20
#
#         Product_Category_2  Product_Category_3  Purchase
# 0                      NaN                 NaN      8370
# 1                      6.0                14.0     15200
# 2                      NaN                 NaN      1422
# 3                     14.0                 NaN      1057
# 4                      NaN                 NaN      7969
# ...                    ...                 ...       ...
# 550063                 NaN                 NaN       368
# 550064                 NaN                 NaN       371
# 550065                 NaN                 NaN       137
# 550066                 NaN                 NaN       365
# 550067                 NaN                 NaN       490
#
# [550068 rows x 12 columns]

# %% [markdown]
# ### => No row is Duplicate

# %%
sale['Purchase'].sum()
# Out:
# 5095812742

# %%
sale.nunique()
# Out:
# User_ID                        5891
# Product_ID                     3631
# Gender                            2
# Age                               7
# Occupation                       21
# City_Category                     3
# Stay_In_Current_City_Years        5
# Marital_Status                    2
# Product_Category_1               20
# Product_Category_2               17
# Product_Category_3               15
# Purchase                      18105
# dtype: int64

# %%
# Counting Null values in each column

print(sale.isnull().sum())
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            173638
# Product_Category_3            383247
# Purchase                           0
# dtype: int64

# %% [markdown]
# ### => Product Category 2 and 3 have many null values

# %%
# Changing Null values to 0

sale["Product_Category_2" ]=sale["Product_Category_2"].fillna(0)
sale["Product_Category_3"]=sale["Product_Category_3"].fillna(0)

# %% [raw]
# # Now no Null values
#
# print(sale.isnull().sum())

# %% [markdown]
# ## -----------------------------------------------------------------------------------------

# %%
# Histogram of Purchase distribution  

sale['Purchase'].plot(kind='hist',bins=15, 
       edgecolor = 'black',figsize=(10,6.5),title='Purchase Distribution')
plt.show()

# %% [markdown]
# ### Most of the purchases are between 5000 and 10000
# ### We have some outliers purchases above 20000

# %% [markdown]
# ## -----------------------------------------------------------------------------------------

# %% [markdown]
# # Checking Outliers

# %%
sns.boxplot(sale.Purchase);
# Out:
# C:\Users\KIIT\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
q1 = sale.Purchase.quantile(0.25)
q3 = sale.Purchase.quantile(0.75)
iqr = q3-q1

upper = q3+1.5*iqr

print(upper)
# Out:
# 21400.5

# %% [markdown]
# # Correlation Of Data

# %%
plt.figure(figsize = (10,6))
sns.heatmap(sale.corr(), annot = True)
plt.title("Correlation", fontsize = 20);

# %% [markdown]
# ## Analysis based on Gender

# %%
# Genders used in Dataset

print(sale["Gender"].unique())
# Out:
# ['F' 'M']

# %%
# Count of Males and Females in Dataset
# Pie Chart on gender distribution

gender_count=sale["Gender"].value_counts()
display(gender_count)

plt.style.use('Solarize_Light2')
gender_count.plot(kind='pie',autopct='%1.1f%%',subplots=True,title='Distribution of Gender',figsize=(12,7))
plt.show()
# Out:
# M    414259
# F    135809
# Name: Gender, dtype: int64

# %% [markdown]
# #### => Males have shopped more than Females

# %% [raw]
# Gen_pur = sale.groupby(["Gender"])[["Purchase"]].sum().sort_values("Purchase")
#
# Gen_pur_formatted = pd.DataFrame(Gen_pur)
# Gen_pur_formatted["Purchase"] = Gen_pur_formatted["Purchase"].apply(lambda x: "{:.2f}".format(x))
#
# # Display the DataFrame
# display(Gen_pur_formatted)

# %%
# Total Purchase by each gender
# Pie chart on Total Purchase by different genders

Gen_pur=sale.groupby(["Gender"])[["Purchase"]].sum().sort_values("Purchase")
display(Gen_pur)

Gen_pur.plot(kind='pie',autopct='%1.1f%%',subplots=True,figsize=(15,7),title='Gender and Total Purchases')
plt.show()
# Out:
#           Purchase
# Gender
# F       1186232642
# M       3909580100

# %% [markdown]
# #### => Males spend more than Females

# %% [raw]
# # Bar Plot on Total Purchase by different genders
#
#
# plt.figure(figsize=(12,8))
#
# Gen_pur["Gender"]=Gen_pur.index
# ax=sns.barplot(data=Gen_pur,x="Gender",y="Purchase")
# ax.bar_label(ax.containers[0])
# plt.title("Gender Vs Purchase",fontsize=18)
# plt.show(ax)

# %% [markdown]
# ## ----------------------------------------------------------------------------------------

# %% [markdown]
# ## Analysis based on Age

# %%
# Categories of people by Age 

print(sale["Age"].unique())
# Out:
# ['0-17' '55+' '26-35' '46-50' '51-55' '36-45' '18-25']

# %%
age_count=sale["Age"].value_counts()
print(age_count)

plt.style.use('Solarize_Light2')
age_count.plot(kind='pie',autopct='%1.1f%%',subplots=True,title='Distribution of Age',figsize=(12,7))
plt.show()
# Out:
# 26-35    219587
# 36-45    110013
# 18-25     99660
# 46-50     45701
# 51-55     38501
# 55+       21504
# 0-17      15102
# Name: Age, dtype: int64

# %%
# Money spent according to age group

Age_pur=sale.groupby(["Age"])[["Purchase"]].sum()
display(Age_pur)
# Out:
#          Purchase
# Age
# 0-17    134913183
# 18-25   913848675
# 26-35  2031770578
# 36-45  1026569884
# 46-50   420843403
# 51-55   367099644
# 55+     200767375

# %%
# Bar Plot of total purchase based on age category
# And Horizontal bar plot of same

ax=sale.groupby(["Age"])[["Purchase"]].sum()
ax["Age"]=ax.index

plt.figure(figsize=(12,8))
ay=sns.barplot(data=ax,x="Age",y="Purchase")
ay.bar_label(ay.containers[0])
plt.title("Age Vs Purchase",fontsize=18)
plt.show()

ax.plot(kind='barh')
plt.show()

# %% [markdown]
# #### => The 26-35 age category has the highest purchases amount

# %% [markdown]
# ## ----------------------------------------------------------------------------------

# %% [markdown]
# ## Analysis based on City

# %%
# Cities

print(sale["City_Category"].unique())
# Out:
# ['A' 'C' 'B']

# %%
# Number of times Shopped from different cities

display(sale["City_Category"].value_counts(sort=True))
# Out:
# B    231173
# C    171175
# A    147720
# Name: City_Category, dtype: int64

# %%
# Number of times shopped from different cities by respective Gender

display(sale.groupby(["City_Category"])[["Gender"]].value_counts())
# Out:
# City_Category  Gender
# A              M         112016
#                F          35704
# B              M         173377
#                F          57796
# C              M         128866
#                F          42309
# dtype: int64

# %%
# Pie chart on Total money spent from each city percentage wise

City_pur=sale.groupby(["City_Category"])[["Purchase"]].sum()
display(City_pur.sort_values("Purchase",ascending=False))

City_pur.plot(kind='pie',autopct='%1.1f%%',subplots=True,figsize=(15,7),title='Total Purchase of different cities')
plt.show()
# Out:
#                  Purchase
# City_Category
# B              2115533605
# C              1663807476
# A              1316471661

# %% [markdown]
# #### => City B has highest sale

# %%
# Bar plot of same as above

City_pur["City_Category"]=City_pur.index

plt.figure(figsize=(12,8))
az=sns.barplot(data=City_pur,x="City_Category",y="Purchase")
az.bar_label(az.containers[0])
plt.title("City_Category Vs Purchase")
plt.show()

# %% [markdown]
# #### => City B has the highest purchase amount

# %%
# Horizonatl Bar plot on Customers purchases by their years in a city
stay=sale.groupby(['Stay_In_Current_City_Years'])[['Purchase']].sum()
display(stay.sort_values("Purchase",ascending=False))

stay.plot(kind='barh',title='Customers purchases by their years in the city',figsize=(12,8))
plt.show()
# Out:
#                               Purchase
# Stay_In_Current_City_Years
# 1                           1792872533
# 2                            949173931
# 3                            884902659
# 4+                           785884390
# 0                            682979229

# %% [markdown]
# #### => It's seems that the longer the customer stays in the city, the more their purchases are less. Maybe their purchase is scattered from different markets.

# %% [markdown]
# ## ------------------------------------------------------------------------------

# %% [markdown]
# ## Analysis based on Product_ID

# %%
# Total number of items

print(len(sale["Product_ID"].unique()))
# Out:
# 3631

# %%
# Number of each product sold

display(sale["Product_ID"].value_counts(sort=True))
# Out:
# P00265242    1880
# P00025442    1615
# P00110742    1612
# P00112142    1562
# P00057642    1470
#              ...
# P00314842       1
# P00298842       1
# P00231642       1
# P00204442       1
# P00066342       1
# Name: Product_ID, Length: 3631, dtype: int64

# %%
# Total yield by each item

display(sale.groupby(["Product_ID"])[["Purchase"]].sum().sort_values("Purchase",ascending=False))
# Out:
#             Purchase
# Product_ID
# P00025442   27995166
# P00110742   26722309
# P00255842   25168963
# P00059442   24338343
# P00184942   24334887
# ...              ...
# P00012942       1717
# P00325342       1656
# P00353042       1545
# P00309042        726
# P00091742        405
#
# [3631 rows x 1 columns]

# %%
# Number and Product id of item purchased by each user 

display(sale.groupby(["User_ID"])[["Product_ID"]].value_counts(sort=True))
# Out:
# User_ID  Product_ID
# 1000001  P00000142     1
#          P00004842     1
#          P00142242     1
#          P00297042     1
#          P00289942     1
#                       ..
# 1006040  P00146442     1
#          P00145742     1
#          P00143142     1
#          P00134342     1
#          P00349442     1
# Length: 550068, dtype: int64

# %%
# It shows approximately that the item is for which gender or unisex

display(sale.groupby(["Product_ID"])[["Gender"]].value_counts(sort=True))
# Out:
# Product_ID  Gender
# P00000142   M         805
#             F         347
# P00000242   M         285
#             F          91
# P00000342   M         175
#                      ...
# P0099742    F          44
# P0099842    F          51
#             M          51
# P0099942    F           7
#             M           7
# Length: 6955, dtype: int64

# %%
# It shows approximately that the item is for which age factor

display(sale.groupby(["Product_ID"])[["Age"]].value_counts(sort=True))
# Out:
# Product_ID  Age
# P00000142   26-35    445
#             18-25    259
#             36-45    228
#             46-50     83
#             51-55     57
#                     ...
# P0099942    51-55      4
#             26-35      3
#             18-25      3
#             36-45      2
#             55+        2
# Length: 20875, dtype: int64

# %% [markdown]
# ## -------------------------------------------------------------------------------------------

# %% [markdown]
# ## Analysis based on Occupation`

# %%
# Unique Occupations in Dataset

print(sale["Occupation"].unique())
print(len(sale["Occupation"].unique()))
# Out:
# [10 16 15  7 20  9  1 12 17  0  3  4 11  8 19  2 18  5 14 13  6]
# 21

# %%
# Bar plot on Number of people in each Occupation

oc_count=sale["Occupation"].value_counts(sort=True)
display(oc_count)

oc_count.plot(kind='bar',title='Occupation count',figsize=(12,8))
plt.show()
# Out:
# 4     72308
# 0     69638
# 7     59133
# 1     47426
# 17    40043
# 20    33562
# 12    31179
# 14    27309
# 2     26588
# 16    25371
# 6     20355
# 3     17650
# 10    12930
# 5     12177
# 15    12165
# 11    11586
# 19     8461
# 13     7728
# 18     6622
# 9      6291
# 8      1546
# Name: Occupation, dtype: int64

# %%
# Total Money spent according to Occupation

Occ_pur=sale.groupby(["Occupation"])[["Purchase"]].sum()
display(Occ_pur.sort_values("Purchase",ascending=False))
# Out:
#              Purchase
# Occupation
# 4           666244484
# 0           635406958
# 7           557371587
# 1           424614144
# 17          393281453
# 12          305449446
# 20          296570442
# 14          259454692
# 16          238346955
# 2           238028583
# 6           188416784
# 3           162002168
# 15          118960211
# 10          115844465
# 5           113649759
# 11          106751618
# 19           73700617
# 13           71919481
# 18           60721461
# 9            54340046
# 8            14737388

# %%
# Bar plot on Occupation VS Purchase

Occ_pur["Occupation"]=Occ_pur.index

plt.figure(figsize=(12,8))
aa=sns.barplot(data=Occ_pur,x="Occupation",y="Purchase")
aa.bar_label(aa.containers[0])
plt.title("Occupation vs Purchase",fontsize=18)
plt.show()

# %%
# Occupation pursued by which gender

display(sale.groupby(["Occupation"])[["Gender"]].value_counts())
# Out:
# Occupation  Gender
# 0           M         51526
#             F         18112
# 1           M         29442
#             F         17984
# 2           M         17959
#             F          8629
# 3           M          9731
#             F          7919
# 4           M         54472
#             F         17836
# 5           M          9957
#             F          2220
# 6           M         12195
#             F          8160
# 7           M         49105
#             F         10028
# 8           M          1185
#             F           361
# 9           F          5843
#             M           448
# 10          M          8927
#             F          4003
# 11          M         10086
#             F          1500
# 12          M         27710
#             F          3469
# 13          M          6230
#             F          1498
# 14          M         20546
#             F          6763
# 15          M          9775
#             F          2390
# 16          M         21264
#             F          4107
# 17          M         36114
#             F          3929
# 18          M          6392
#             F           230
# 19          M          6444
#             F          2017
# 20          M         24751
#             F          8811
# dtype: int64

# %% [markdown]
# ## -------------------------------------------------------------------------------------------

# %% [markdown]
# ## Analysis based on Marital Status
# ### 0 = Unmarried | 1 = Married

# %%
# Pie chart on customer marital status

ma_pur=sale.groupby(['Marital_Status'])[['Purchase']].sum()
display(ma_pur)

ma_pur.plot(kind='pie',autopct="%1.1f%%",title="Marital Status VS TotalPurchase",subplots=True,figsize=(12,8))
plt.show()
# Out:
#                   Purchase
# Marital_Status
# 0               3008927447
# 1               2086885295

# %% [markdown]
# #### => Singles buy more than married people

# %%
display(sale.groupby(["Gender","Marital_Status"])[["Purchase"]].sum())
# Out:
#                          Purchase
# Gender Marital_Status
# F      0                684154127
#        1                502078515
# M      0               2324773320
#        1               1584806780

# %% [markdown]
# #### => Single Males are more shopping

# %% [markdown]
# ## -------------------------------------------------------------------------------------

# %% [markdown]
# ## Product category Analysis

# %%
# Which product category in category 1 have yield how much sales

Pr_pur=sale.pivot_table(index="Product_Category_1",values="Purchase",aggfunc="sum").sort_values("Purchase")
display(Pr_pur)
# Out:
#                       Purchase
# Product_Category_1
# 19                       59378
# 20                      944727
# 13                     4008601
# 12                     5331844
# 17                     5878699
# 9                      6370324
# 18                     9290201
# 14                    20014696
# 4                     27380488
# 7                     60896731
# 15                    92969042
# 10                   100837301
# 11                   113791115
# 16                   145120612
# 3                    204084713
# 2                    268516186
# 6                    324150302
# 8                    854318799
# 5                    941835229
# 1                   1910013754

# %%
# Horizontal bar plot on product catgory 1 and its total sales

plt.figure(figsize=(12,8))

Pr_pur["Product_Category_1"]=Pr_pur.index

Pr_pur.plot(kind='barh')
plt.title("Product_Category_1 by Purchases",fontsize=20)
plt.show()

# %% [markdown]
# ## --------------------------------

# %%
# Which product category in category 2 have yield how much sales

Pr_pur2=sale.pivot_table(index="Product_Category_2",values="Purchase",aggfunc="sum").sort_values("Purchase")
display(Pr_pur2)
# Out:
#                       Purchase
# Product_Category_2
# 7.0                    4309812
# 18.0                  25906260
# 3.0                   32402777
# 12.0                  38560412
# 9.0                   41428000
# 10.0                  47619084
# 13.0                 101975384
# 17.0                 125495400
# 11.0                 126366165
# 6.0                  189417477
# 5.0                  236844899
# 4.0                  262295485
# 14.0                 391556939
# 15.0                 392067176
# 16.0                 445339722
# 8.0                  658392656
# 2.0                  670303864
# 0.0                 1305531230

# %%
# Horizontal bar plot on product catgory 2 and its total sales

plt.figure(figsize=(12,8))
Pr_pur2["Product_Category_2"]=Pr_pur2.index

Pr_pur2.plot(kind='barh')
plt.title("Product_Category_2 vs Purchased",fontsize=20)
plt.show()

# %% [markdown]
# ## ------------------------------------

# %%
# Which product category in category 3 have yield how much sales

Pr_pur3=sale.pivot_table(index="Product_Category_3",values="Purchase",aggfunc="sum").sort_values("Purchase")
display(Pr_pur3)
# Out:
#                       Purchase
# Product_Category_3
# 3.0                    8545034
# 4.0                   18364475
# 11.0                  21825045
# 10.0                  23311034
# 18.0                  50891137
# 6.0                   64520181
# 13.0                  71977563
# 12.0                  80583631
# 9.0                  120788622
# 8.0                  163619031
# 14.0                 185249212
# 17.0                 196581588
# 5.0                  201858094
# 15.0                 345662769
# 16.0                 391040983
# 0.0                 3150994343

# %%
# Horizontal bar plot on product catgory 3 and its total sales

plt.figure(figsize=(12,8))
Pr_pur3["Product_Category_3"]=Pr_pur3.index

Pr_pur3.plot(kind='barh')
plt.title("Product_Category_3 vs Purchased",fontsize=20)
plt.show()

# %% [markdown]
# ## ------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Top 5 Products by Purchases

# %%
# Pie chart on Top 5 products and thier contribution to sales

top_pr=sale.groupby(['Product_ID'])[['Purchase']].sum().sort_values('Purchase',ascending=False)
top_pr=top_pr.head(5)
display(top_pr)

top_pr.plot(kind="pie",autopct="%1.1f%%",subplots=True,title="Top 5 Products by purchase",figsize=(12,10))
plt.show()
# Out:
#             Purchase
# Product_ID
# P00025442   27995166
# P00110742   26722309
# P00255842   25168963
# P00059442   24338343
# P00184942   24334887

# %% [markdown]
# ## Converting Gender, categorical data to integer

# %%
df_gender = pd.get_dummies(sale['Gender'])

# %%
sale_new = pd.concat([sale, df_gender], axis=1)
display(sale_new)
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# 1                               2               0                   1
# 2                               2               0                  12
# 3                               2               0                  12
# 4                              4+               0                   8
# ...                           ...             ...                 ...
# 550063                          1               1                  20
# 550064                          3               0                  20
# 550065                         4+               1                  20
# 550066                          2               0                  20
# 550067                         4+               1                  20
#
#         Product_Category_2  Product_Category_3  Purchase  F  M
# 0                      0.0                 0.0      8370  1  0
# 1                      6.0                14.0     15200  1  0
# 2                      0.0                 0.0      1422  1  0
# 3                     14.0                 0.0      1057  1  0
# 4                      0.0                 0.0      7969  0  1
# ...                    ...                 ...       ... .. ..
# 550063                 0.0                 0.0       368  0  1
# 550064                 0.0                 0.0       371  1  0
# 550065                 0.0                 0.0       137  1  0
# 550066                 0.0                 0.0       365  1  0
# 550067                 0.0                 0.0       490  1  0
#
# [550068 rows x 14 columns]

# %%
# Dropping useless columns for Sales Data

sale_new.drop(["Gender","Occupation","Stay_In_Current_City_Years","Marital_Status","City_Category"],axis=1,inplace=True)

# %%
# Our new informative data set(useful)

display(sale_new)
# Out:
#         User_ID Product_ID    Age  Product_Category_1  Product_Category_2  \
# 0       1000001  P00069042   0-17                   3                 0.0
# 1       1000001  P00248942   0-17                   1                 6.0
# 2       1000001  P00087842   0-17                  12                 0.0
# 3       1000001  P00085442   0-17                  12                14.0
# 4       1000002  P00285442    55+                   8                 0.0
# ...         ...        ...    ...                 ...                 ...
# 550063  1006033  P00372445  51-55                  20                 0.0
# 550064  1006035  P00375436  26-35                  20                 0.0
# 550065  1006036  P00375436  26-35                  20                 0.0
# 550066  1006038  P00375436    55+                  20                 0.0
# 550067  1006039  P00371644  46-50                  20                 0.0
#
#         Product_Category_3  Purchase  F  M
# 0                      0.0      8370  1  0
# 1                     14.0     15200  1  0
# 2                      0.0      1422  1  0
# 3                      0.0      1057  1  0
# 4                      0.0      7969  0  1
# ...                    ...       ... .. ..
# 550063                 0.0       368  0  1
# 550064                 0.0       371  1  0
# 550065                 0.0       137  1  0
# 550066                 0.0       365  1  0
# 550067                 0.0       490  1  0
#
# [550068 rows x 9 columns]

# %%
sale
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# 1                               2               0                   1
# 2                               2               0                  12
# 3                               2               0                  12
# 4                              4+               0                   8
# ...                           ...             ...                 ...
# 550063                          1               1                  20
# 550064                          3               0                  20
# 550065                         4+               1                  20
# 550066                          2               0                  20
# 550067                         4+               1                  20
#
#         Product_Category_2  Product_Category_3  Purchase
# 0                      0.0                 0.0      8370
# 1                      6.0                14.0     15200
# 2                      0.0                 0.0      1422
# 3                     14.0                 0.0      1057
# 4                      0.0                 0.0      7969
# ...                    ...                 ...       ...
# 550063                 0.0                 0.0       368
# 550064                 0.0                 0.0       371
# 550065                 0.0                 0.0       137
# 550066                 0.0                 0.0       365
# 550067                 0.0                 0.0       490
#
# [550068 rows x 12 columns]

# %% [markdown]
# # ----------------------------------------------------------------------------------

# %% [markdown]
# # Encoding

# %%
sale.Stay_In_Current_City_Years = sale.Stay_In_Current_City_Years.replace("4+", 4)
sale.Stay_In_Current_City_Years = sale.Stay_In_Current_City_Years.astype("int64")

sale.Age = sale.Age.replace("0-17", 17)
sale.Age = sale.Age.replace("18-25", 25)
sale.Age = sale.Age.replace("26-35", 35)
sale.Age = sale.Age.replace("36-45", 45)
sale.Age = sale.Age.replace("46-50", 50)
sale.Age = sale.Age.replace("51-55", 55)
sale.Age = sale.Age.replace("55+", 60)
sale.Age = sale.Age.astype("int64")

sale.Product_ID = sale.Product_ID.str.replace("P00", "")
sale.Product_ID = sale.Product_ID.astype("int64")

# %% [raw]
# df2['Gender']=pd.factorize(df2.Gender)[0]
# df2['Age']=pd.factorize(df2.Age)[0]
# df2['City_Category']=pd.factorize(df2.City_Category)[0]
# df2['Stay_In_Current_City_Years']=pd.factorize(df2.Stay_In_Current_City_Years)[0]
# df2['Product_ID']=pd.factorize(df2.Product_ID)[0]
# df2['User_ID']=pd.factorize(df2.User_ID)[0]

# %%
sale
# Out:
#         User_ID  Product_ID Gender  Age  Occupation City_Category  \
# 0       1000001       69042      F   17          10             A
# 1       1000001      248942      F   17          10             A
# 2       1000001       87842      F   17          10             A
# 3       1000001       85442      F   17          10             A
# 4       1000002      285442      M   60          16             C
# ...         ...         ...    ...  ...         ...           ...
# 550063  1006033      372445      M   55          13             B
# 550064  1006035      375436      F   35           1             C
# 550065  1006036      375436      F   35          15             B
# 550066  1006038      375436      F   60           1             C
# 550067  1006039      371644      F   50           0             B
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                                2               0                   3
# 1                                2               0                   1
# 2                                2               0                  12
# 3                                2               0                  12
# 4                                4               0                   8
# ...                            ...             ...                 ...
# 550063                           1               1                  20
# 550064                           3               0                  20
# 550065                           4               1                  20
# 550066                           2               0                  20
# 550067                           4               1                  20
#
#         Product_Category_2  Product_Category_3  Purchase
# 0                      0.0                 0.0      8370
# 1                      6.0                14.0     15200
# 2                      0.0                 0.0      1422
# 3                     14.0                 0.0      1057
# 4                      0.0                 0.0      7969
# ...                    ...                 ...       ...
# 550063                 0.0                 0.0       368
# 550064                 0.0                 0.0       371
# 550065                 0.0                 0.0       137
# 550066                 0.0                 0.0       365
# 550067                 0.0                 0.0       490
#
# [550068 rows x 12 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
xx=le.fit_transform(sale['Gender'])
sale['Gender'] = xx

# %%
sale = pd.get_dummies(sale, columns = ["City_Category"], prefix = ["City"])

# %%
sale
# Out:
#         User_ID  Product_ID  Gender  Age  Occupation  \
# 0       1000001       69042       0   17          10
# 1       1000001      248942       0   17          10
# 2       1000001       87842       0   17          10
# 3       1000001       85442       0   17          10
# 4       1000002      285442       1   60          16
# ...         ...         ...     ...  ...         ...
# 550063  1006033      372445       1   55          13
# 550064  1006035      375436       0   35           1
# 550065  1006036      375436       0   35          15
# 550066  1006038      375436       0   60           1
# 550067  1006039      371644       0   50           0
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                                2               0                   3
# 1                                2               0                   1
# 2                                2               0                  12
# 3                                2               0                  12
# 4                                4               0                   8
# ...                            ...             ...                 ...
# 550063                           1               1                  20
# 550064                           3               0                  20
# 550065                           4               1                  20
# 550066                           2               0                  20
# 550067                           4               1                  20
#
#         Product_Category_2  Product_Category_3  Purchase  City_A  City_B  \
# 0                      0.0                 0.0      8370       1       0
# 1                      6.0                14.0     15200       1       0
# 2                      0.0                 0.0      1422       1       0
# 3                     14.0                 0.0      1057       1       0
# 4                      0.0                 0.0      7969       0       0
# ...                    ...                 ...       ...     ...     ...
# 550063                 0.0                 0.0       368       0       1
# 550064                 0.0                 0.0       371       0       0
# 550065                 0.0                 0.0       137       0       1
# 550066                 0.0                 0.0       365       0       0
# 550067                 0.0                 0.0       490       0       1
#
#         City_C
# 0            0
# 1            0
# 2            0
# 3            0
# 4            1
# ...        ...
# 550063       0
# 550064       1
# 550065       0
# 550066       1
# 550067       0
#
# [550068 rows x 14 columns]

# %%
pd.DataFrame(abs(sale.corr()["Purchase"]).sort_values(ascending = False)).iloc[1:]
# Out:
#                             Purchase
# Product_Category_1          0.343703
# Product_Category_3          0.288501
# Product_ID                  0.103961
# City_C                      0.061012
# Gender                      0.060346
# Product_Category_2          0.052288
# City_A                      0.042465
# Occupation                  0.020833
# City_B                      0.019098
# Age                         0.016345
# Stay_In_Current_City_Years  0.005422
# User_ID                     0.004716
# Marital_Status              0.000463

# %% [markdown]
# ### Dropping these as they have no importance

# %%
sale.drop(['Marital_Status','City_B'], axis = 1, inplace = True)

# %%
sale
# Out:
#         User_ID  Product_ID  Gender  Age  Occupation  \
# 0       1000001       69042       0   17          10
# 1       1000001      248942       0   17          10
# 2       1000001       87842       0   17          10
# 3       1000001       85442       0   17          10
# 4       1000002      285442       1   60          16
# ...         ...         ...     ...  ...         ...
# 550063  1006033      372445       1   55          13
# 550064  1006035      375436       0   35           1
# 550065  1006036      375436       0   35          15
# 550066  1006038      375436       0   60           1
# 550067  1006039      371644       0   50           0
#
#         Stay_In_Current_City_Years  Product_Category_1  Product_Category_2  \
# 0                                2                   3                 0.0
# 1                                2                   1                 6.0
# 2                                2                  12                 0.0
# 3                                2                  12                14.0
# 4                                4                   8                 0.0
# ...                            ...                 ...                 ...
# 550063                           1                  20                 0.0
# 550064                           3                  20                 0.0
# 550065                           4                  20                 0.0
# 550066                           2                  20                 0.0
# 550067                           4                  20                 0.0
#
#         Product_Category_3  Purchase  City_A  City_C
# 0                      0.0      8370       1       0
# 1                     14.0     15200       1       0
# 2                      0.0      1422       1       0
# 3                      0.0      1057       1       0
# 4                      0.0      7969       0       1
# ...                    ...       ...     ...     ...
# 550063                 0.0       368       0       0
# 550064                 0.0       371       0       1
# 550065                 0.0       137       0       0
# 550066                 0.0       365       0       1
# 550067                 0.0       490       0       0
#
# [550068 rows x 12 columns]

# %% [markdown]
# # X and y

# %%
X=sale.drop(['Purchase','User_ID'],axis=1).values
X
# Out:
# array([[6.90420e+04, 0.00000e+00, 1.70000e+01, ..., 0.00000e+00,
#         1.00000e+00, 0.00000e+00],
#        [2.48942e+05, 0.00000e+00, 1.70000e+01, ..., 1.40000e+01,
#         1.00000e+00, 0.00000e+00],
#        [8.78420e+04, 0.00000e+00, 1.70000e+01, ..., 0.00000e+00,
#         1.00000e+00, 0.00000e+00],
#        ...,
#        [3.75436e+05, 0.00000e+00, 3.50000e+01, ..., 0.00000e+00,
#         0.00000e+00, 0.00000e+00],
#        [3.75436e+05, 0.00000e+00, 6.00000e+01, ..., 0.00000e+00,
#         0.00000e+00, 1.00000e+00],
#        [3.71644e+05, 0.00000e+00, 5.00000e+01, ..., 0.00000e+00,
#         0.00000e+00, 0.00000e+00]])

# %%
y=sale['Purchase'].values
y
# Out:
# array([ 8370, 15200,  1422, ...,   137,   365,   490], dtype=int64)

# %% [markdown]
# # Scaling

# %%
from sklearn.preprocessing import StandardScaler

sc_x= StandardScaler()
X_scaled = sc_x.fit_transform(X)

# %% [markdown]
# # Splitting

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size = 0.30, random_state = 100)
X_train,y_train
# Out:
# (array([[ 0.68710115,  0.57256962, -1.28665643, ..., -0.61464112,
#          -0.6059248 ,  1.48777797],
#         [ 0.45546291,  0.57256962,  1.12869972, ..., -0.61464112,
#          -0.6059248 , -0.67214331],
#         [ 1.06959621,  0.57256962, -0.32051397, ..., -0.61464112,
#           1.65036982, -0.67214331],
#         ...,
#         [-0.98205671,  0.57256962,  0.64562849, ...,  2.10505135,
#          -0.6059248 , -0.67214331],
#         [ 1.08906161,  0.57256962, -0.32051397, ..., -0.61464112,
#          -0.6059248 , -0.67214331],
#         [ 0.08270055,  0.57256962, -0.32051397, ..., -0.61464112,
#          -0.6059248 ,  1.48777797]]),
#  array([ 4444,  5385,  3523, ..., 15284,  4494,  7048], dtype=int64))

# %% [markdown]
# # XGB Regressor

# %%
from xgboost import XGBRegressor
from sklearn.metrics import r2_score
xgbm = XGBRegressor(n_jobs=-1,
    n_estimators=1000,
    alpha= 3.6353429991712695e-08,
    subsample= 0.9423675532438815,
    colsample_bytree= 0.9830450413657872,
    min_child_weight= 8,
    eta= 0.3749337530972536,
    gamma= 0.0745370910451703,
    grow_policy= 'depthwise')
xgbm.fit(X_train, y_train)
# Out:
# XGBRegressor(alpha=3.6353429991712695e-08, base_score=None, booster=None,
#              callbacks=None, colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.9830450413657872, early_stopping_rounds=None,
#              enable_categorical=False, eta=0.3749337530972536, eval_metric=None,
#              feature_types=None, gamma=0.0745370910451703, gpu_id=None,
#              grow_policy='depthwise', importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=8, missing=nan, monotone_constraints=None,
#              n_estimators=1000, n_jobs=-1, num_parallel_tree=None, ...)

# %%
pred = xgbm.predict(X_test)
pred[pred<0] = 0

r2_score(pred, y_test)
# Out:
# 0.6370368508003306

# %%
y_df = pd.DataFrame(sale["Purchase"])

predict = np.floor(xgbm.predict(X))
y_df["Predict"] = predict
y_df
# Out:
#         Purchase  Predict
# 0           8370   9083.0
# 1          15200  17295.0
# 2           1422  -1578.0
# 3           1057    427.0
# 4           7969  -1276.0
# ...          ...      ...
# 550063       368   -629.0
# 550064       371   -876.0
# 550065       137   -916.0
# 550066       365   -876.0
# 550067       490    527.0
#
# [550068 rows x 2 columns]

# %% [markdown]
# ***Gradient Boosting models can return values inside and outside of the training range. So our model predicted some negative values. We need to convert negative values to zero.***

# %%
predict[predict<0] = 0
y_df["Predict"] = predict

y_df.tail()
# Out:
#         Purchase  Predict
# 550063       368      0.0
# 550064       371      0.0
# 550065       137      0.0
# 550066       365      0.0
# 550067       490    527.0

# %%
plt.style.use("ggplot")
plt.figure(figsize = (15,6))

plt.plot(y_df[0:40]["Purchase"], color = "b", label = "Real Value")
plt.plot(y_df[0:40]["Predict"], color = "r", label = "Predicted Value")
plt.legend()
plt.title("Real vs Predicted Values", fontsize = 30)
plt.show()

# %% [markdown]
# # Random Forest Regression

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
rfr = RandomForestRegressor()
rfr.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %%
score = rfr.score(X_train,y_train)
score
# Out:
# 0.9221554996720541

# %%
y_pred5 = rfr.predict(X_test)
rscore=r2_score(y_test, y_pred5)
rscore
# Out:
# 0.665475675169765

# %%
x_ax = range(len(y_test))
plt.plot(x_ax, y_test, linewidth = '1', label="original")
plt.plot(x_ax, y_pred5, linewidth = '1', label="predicted")
plt.title("Test data VS Predicted data")
plt.xlabel('X')
plt.ylabel('Y')
plt.legend(loc='lower right',fancybox=True, shadow=True)
plt.show()

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeRegressor
regressor = DecisionTreeRegressor(random_state = 0)
regressor.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(random_state=0)

# %%
y_pred = regressor.predict(X_test)
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))
# Out:
# [[ 1673.   3051. ]
#  [13698.  13692. ]
#  [ 8881.   8592. ]
#  ...
#  [ 7715.5  3999. ]
#  [21023.  17129. ]
#  [ 5153.   8779. ]]

# %%
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# 0.4680137665604498
